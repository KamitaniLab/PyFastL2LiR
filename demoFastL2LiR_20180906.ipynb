# %%
#Module import
import fastL2LiR_v1
import numpy
import time

# %%
#Preparation for simulation analysis
X=numpy.random.rand(1200,5000)# The number of samples x The number of voxels
Y=numpy.random.rand(1200,1000)# The number of samples x The number of CNN features
alpha=1.0 #Regularization parameter (coefficient for L2-norm)
numUsedInputFeatures=500 # The number of voxels after feature selection with correlation coefficients.
#Prepare a model object (like scikit-learn functions)
model = fastL2LiR_v1.fastL2LiR()
# Out:
# fast L2 linear regression

# %%
#Training start
startTime=time.time()
model.fit(X,Y,alpha,numUsedInputFeatures)
print 'Time for decoder training: ' + str(time.time()-startTime) + ' seconds'

#Prediction
predicted=model.predict(X)
# Out:
# 0-th output dim finished
# 1-th output dim finished
# 2-th output dim finished
# 3-th output dim finished
# 4-th output dim finished
# 5-th output dim finished
# 6-th output dim finished
# 7-th output dim finished
# 8-th output dim finished
# 9-th output dim finished
# 10-th output dim finished
# 11-th output dim finished
# 12-th output dim finished
# 13-th output dim finished
# 14-th output dim finished
# 15-th output dim finished
# 16-th output dim finished
# 17-th output dim finished
# 18-th output dim finished
# 19-th output dim finished
# 20-th output dim finished
# 21-th output dim finished
# 22-th output dim finished
# 23-th output dim finished
# 24-th output dim finished
# 25-th output dim finished
# 26-th output dim finished
# 27-th output dim finished
# 28-th output dim finished
# 29-th output dim finished
# 30-th output dim finished
# 31-th output dim finished
# 32-th output dim finished
# 33-th output dim finished
# 34-th output dim finished
# 35-th output dim finished
# 36-th output dim finished
# 37-th output dim finished
# 38-th output dim finished
# 39-th output dim finished
# 40-th output dim finished
# 41-th output dim finished
# 42-th output dim finished
# 43-th output dim finished
# 44-th output dim finished
# 45-th output dim finished
# 46-th output dim finished
# 47-th output dim finished
# 48-th output dim finished
# 49-th output dim finished
# 50-th output dim finished
# 51-th output dim finished
# 52-th output dim finished
# 53-th output dim finished
# 54-th output dim finished
# 55-th output dim finished
# 56-th output dim finished
# 57-th output dim finished
# 58-th output dim finished
# 59-th output dim finished
# 60-th output dim finished
# 61-th output dim finished
# 62-th output dim finished
# 63-th output dim finished
# 64-th output dim finished
# 65-th output dim finished
# 66-th output dim finished
# 67-th output dim finished
# 68-th output dim finished
# 69-th output dim finished
# 70-th output dim finished
# 71-th output dim finished
# 72-th output dim finished
# 73-th output dim finished
# 74-th output dim finished
# 75-th output dim finished
# 76-th output dim finished
# 77-th output dim finished
# 78-th output dim finished
# 79-th output dim finished
# 80-th output dim finished
# 81-th output dim finished
# 82-th output dim finished
# 83-th output dim finished
# 84-th output dim finished
# 85-th output dim finished
# 86-th output dim finished
# 87-th output dim finished
# 88-th output dim finished
# 89-th output dim finished
# 90-th output dim finished
# 91-th output dim finished
# 92-th output dim finished
# 93-th output dim finished
# 94-th output dim finished
# 95-th output dim finished
# 96-th output dim finished
# 97-th output dim finished
# 98-th output dim finished
# 99-th output dim finished
# 100-th output dim finished
# 101-th output dim finished
# 102-th output dim finished
# 103-th output dim finished
# 104-th output dim finished
# 105-th output dim finished
# 106-th output dim finished
# 107-th output dim finished
# 108-th output dim finished
# 109-th output dim finished
# 110-th output dim finished
# 111-th output dim finished
# 112-th output dim finished
# 113-th output dim finished
# 114-th output dim finished
# 115-th output dim finished
# 116-th output dim finished
# 117-th output dim finished
# 118-th output dim finished
# 119-th output dim finished
# 120-th output dim finished
# 121-th output dim finished
# 122-th output dim finished
# 123-th output dim finished
# 124-th output dim finished
# 125-th output dim finished
# 126-th output dim finished
# 127-th output dim finished
# 128-th output dim finished
# 129-th output dim finished
# 130-th output dim finished
# 131-th output dim finished
# 132-th output dim finished
# 133-th output dim finished
# 134-th output dim finished
# 135-th output dim finished
# 136-th output dim finished
# 137-th output dim finished
# 138-th output dim finished
# 139-th output dim finished
# 140-th output dim finished
# 141-th output dim finished
# 142-th output dim finished
# 143-th output dim finished
# 144-th output dim finished
# 145-th output dim finished
# 146-th output dim finished
# 147-th output dim finished
# 148-th output dim finished
# 149-th output dim finished
# 150-th output dim finished
# 151-th output dim finished
# 152-th output dim finished
# 153-th output dim finished
# 154-th output dim finished
# 155-th output dim finished
# 156-th output dim finished
# 157-th output dim finished
# 158-th output dim finished
# 159-th output dim finished
# 160-th output dim finished
# 161-th output dim finished
# 162-th output dim finished
# 163-th output dim finished
# 164-th output dim finished
# 165-th output dim finished
# 166-th output dim finished
# 167-th output dim finished
# 168-th output dim finished
# 169-th output dim finished
# 170-th output dim finished
# 171-th output dim finished
# 172-th output dim finished
# 173-th output dim finished
# 174-th output dim finished
# 175-th output dim finished
# 176-th output dim finished
# 177-th output dim finished
# 178-th output dim finished
# 179-th output dim finished
# 180-th output dim finished
# 181-th output dim finished
# 182-th output dim finished
# 183-th output dim finished
# 184-th output dim finished
# 185-th output dim finished
# 186-th output dim finished
# 187-th output dim finished
# 188-th output dim finished
# 189-th output dim finished
# 190-th output dim finished
# 191-th output dim finished
# 192-th output dim finished
# 193-th output dim finished
# 194-th output dim finished
# 195-th output dim finished
# 196-th output dim finished
# 197-th output dim finished
# 198-th output dim finished
# 199-th output dim finished
# 200-th output dim finished
# 201-th output dim finished
# 202-th output dim finished
# 203-th output dim finished
# 204-th output dim finished
# 205-th output dim finished
# 206-th output dim finished
# 207-th output dim finished
# 208-th output dim finished
# 209-th output dim finished
# 210-th output dim finished
# 211-th output dim finished
# 212-th output dim finished
# 213-th output dim finished
# 214-th output dim finished
# 215-th output dim finished
# 216-th output dim finished
# 217-th output dim finished
# 218-th output dim finished
# 219-th output dim finished
# 220-th output dim finished
# 221-th output dim finished
# 222-th output dim finished
# 223-th output dim finished
# 224-th output dim finished
# 225-th output dim finished
# 226-th output dim finished
# 227-th output dim finished
# 228-th output dim finished
# 229-th output dim finished
# 230-th output dim finished
# 231-th output dim finished
# 232-th output dim finished
# 233-th output dim finished
# 234-th output dim finished
# 235-th output dim finished
# 236-th output dim finished
# 237-th output dim finished
# 238-th output dim finished
# 239-th output dim finished
# 240-th output dim finished
# 241-th output dim finished
# 242-th output dim finished
# 243-th output dim finished
# 244-th output dim finished
# 245-th output dim finished
# 246-th output dim finished
# 247-th output dim finished
# 248-th output dim finished
# 249-th output dim finished
# 250-th output dim finished
# 251-th output dim finished
# 252-th output dim finished
# 253-th output dim finished
# 254-th output dim finished
# 255-th output dim finished
# 256-th output dim finished
# 257-th output dim finished
# 258-th output dim finished
# 259-th output dim finished
# 260-th output dim finished
# 261-th output dim finished
# 262-th output dim finished
# 263-th output dim finished
# 264-th output dim finished
# 265-th output dim finished
# 266-th output dim finished
# 267-th output dim finished
# 268-th output dim finished
# 269-th output dim finished
# 270-th output dim finished
# 271-th output dim finished
# 272-th output dim finished
# 273-th output dim finished
# 274-th output dim finished
# 275-th output dim finished
# 276-th output dim finished
# 277-th output dim finished
# 278-th output dim finished
# 279-th output dim finished
# 280-th output dim finished
# 281-th output dim finished
# 282-th output dim finished
# 283-th output dim finished
# 284-th output dim finished
# 285-th output dim finished
# 286-th output dim finished
# 287-th output dim finished
# 288-th output dim finished
# 289-th output dim finished
# 290-th output dim finished
# 291-th output dim finished
# 292-th output dim finished
# 293-th output dim finished
# 294-th output dim finished
# 295-th output dim finished
# 296-th output dim finished
# 297-th output dim finished
# 298-th output dim finished
# 299-th output dim finished
# 300-th output dim finished
# 301-th output dim finished
# 302-th output dim finished
# 303-th output dim finished
# 304-th output dim finished
# 305-th output dim finished
# 306-th output dim finished
# 307-th output dim finished
# 308-th output dim finished
# 309-th output dim finished
# 310-th output dim finished
# 311-th output dim finished
# 312-th output dim finished
# 313-th output dim finished
# 314-th output dim finished
# 315-th output dim finished
# 316-th output dim finished
# 317-th output dim finished
# 318-th output dim finished
# 319-th output dim finished
# 320-th output dim finished
# 321-th output dim finished
# 322-th output dim finished
# 323-th output dim finished
# 324-th output dim finished
# 325-th output dim finished
# 326-th output dim finished
# 327-th output dim finished
# 328-th output dim finished
# 329-th output dim finished
# 330-th output dim finished
# 331-th output dim finished
# 332-th output dim finished
# 333-th output dim finished
# 334-th output dim finished
# 335-th output dim finished
# 336-th output dim finished
# 337-th output dim finished
# 338-th output dim finished
# 339-th output dim finished
# 340-th output dim finished
# 341-th output dim finished
# 342-th output dim finished
# 343-th output dim finished
# 344-th output dim finished
# 345-th output dim finished
# 346-th output dim finished
# 347-th output dim finished
# 348-th output dim finished
# 349-th output dim finished
# 350-th output dim finished
# 351-th output dim finished
# 352-th output dim finished
# 353-th output dim finished
# 354-th output dim finished
# 355-th output dim finished
# 356-th output dim finished
# 357-th output dim finished
# 358-th output dim finished
# 359-th output dim finished
# 360-th output dim finished
# 361-th output dim finished
# 362-th output dim finished
# 363-th output dim finished
# 364-th output dim finished
# 365-th output dim finished
# 366-th output dim finished
# 367-th output dim finished
# 368-th output dim finished
# 369-th output dim finished
# 370-th output dim finished
# 371-th output dim finished
# 372-th output dim finished
# 373-th output dim finished
# 374-th output dim finished
# 375-th output dim finished
# 376-th output dim finished
# 377-th output dim finished
# 378-th output dim finished
# 379-th output dim finished
# 380-th output dim finished
# 381-th output dim finished
# 382-th output dim finished
# 383-th output dim finished
# 384-th output dim finished
# 385-th output dim finished
# 386-th output dim finished
# 387-th output dim finished
# 388-th output dim finished
# 389-th output dim finished
# 390-th output dim finished
# 391-th output dim finished
# 392-th output dim finished
# 393-th output dim finished
# 394-th output dim finished
# 395-th output dim finished
# 396-th output dim finished
# 397-th output dim finished
# 398-th output dim finished
# 399-th output dim finished
# 400-th output dim finished
# 401-th output dim finished
# 402-th output dim finished
# 403-th output dim finished
# 404-th output dim finished
# 405-th output dim finished
# 406-th output dim finished
# 407-th output dim finished
# 408-th output dim finished
# 409-th output dim finished
# 410-th output dim finished
# 411-th output dim finished
# 412-th output dim finished
# 413-th output dim finished
# 414-th output dim finished
# 415-th output dim finished
# 416-th output dim finished
# 417-th output dim finished
# 418-th output dim finished
# 419-th output dim finished
# 420-th output dim finished
# 421-th output dim finished
# 422-th output dim finished
# 423-th output dim finished
# 424-th output dim finished
# 425-th output dim finished
# 426-th output dim finished
# 427-th output dim finished
# 428-th output dim finished
# 429-th output dim finished
# 430-th output dim finished
# 431-th output dim finished
# 432-th output dim finished
# 433-th output dim finished
# 434-th output dim finished
# 435-th output dim finished
# 436-th output dim finished
# 437-th output dim finished
# 438-th output dim finished
# 439-th output dim finished
# 440-th output dim finished
# 441-th output dim finished
# 442-th output dim finished
# 443-th output dim finished
# 444-th output dim finished
# 445-th output dim finished
# 446-th output dim finished
# 447-th output dim finished
# 448-th output dim finished
# 449-th output dim finished
# 450-th output dim finished
# 451-th output dim finished
# 452-th output dim finished
# 453-th output dim finished
# 454-th output dim finished
# 455-th output dim finished
# 456-th output dim finished
# 457-th output dim finished
# 458-th output dim finished
# 459-th output dim finished
# 460-th output dim finished
# 461-th output dim finished
# 462-th output dim finished
# 463-th output dim finished
# 464-th output dim finished
# 465-th output dim finished
# 466-th output dim finished
# 467-th output dim finished
# 468-th output dim finished
# 469-th output dim finished
# 470-th output dim finished
# 471-th output dim finished
# 472-th output dim finished
# 473-th output dim finished
# 474-th output dim finished
# 475-th output dim finished
# 476-th output dim finished
# 477-th output dim finished
# 478-th output dim finished
# 479-th output dim finished
# 480-th output dim finished
# 481-th output dim finished
# 482-th output dim finished
# 483-th output dim finished
# 484-th output dim finished
# 485-th output dim finished
# 486-th output dim finished
# 487-th output dim finished
# 488-th output dim finished
# 489-th output dim finished
# 490-th output dim finished
# 491-th output dim finished
# 492-th output dim finished
# 493-th output dim finished
# 494-th output dim finished
# 495-th output dim finished
# 496-th output dim finished
# 497-th output dim finished
# 498-th output dim finished
# 499-th output dim finished
# 500-th output dim finished
# 501-th output dim finished
# 502-th output dim finished
# 503-th output dim finished
# 504-th output dim finished
# 505-th output dim finished
# 506-th output dim finished
# 507-th output dim finished
# 508-th output dim finished
# 509-th output dim finished
# 510-th output dim finished
# 511-th output dim finished
# 512-th output dim finished
# 513-th output dim finished
# 514-th output dim finished
# 515-th output dim finished
# 516-th output dim finished
# 517-th output dim finished
# 518-th output dim finished
# 519-th output dim finished
# 520-th output dim finished
# 521-th output dim finished
# 522-th output dim finished
# 523-th output dim finished
# 524-th output dim finished
# 525-th output dim finished
# 526-th output dim finished
# 527-th output dim finished
# 528-th output dim finished
# 529-th output dim finished
# 530-th output dim finished
# 531-th output dim finished
# 532-th output dim finished
# 533-th output dim finished
# 534-th output dim finished
# 535-th output dim finished
# 536-th output dim finished
# 537-th output dim finished
# 538-th output dim finished
# 539-th output dim finished
# 540-th output dim finished
# 541-th output dim finished
# 542-th output dim finished
# 543-th output dim finished
# 544-th output dim finished
# 545-th output dim finished
# 546-th output dim finished
# 547-th output dim finished
# 548-th output dim finished
# 549-th output dim finished
# 550-th output dim finished
# 551-th output dim finished
# 552-th output dim finished
# 553-th output dim finished
# 554-th output dim finished
# 555-th output dim finished
# 556-th output dim finished
# 557-th output dim finished
# 558-th output dim finished
# 559-th output dim finished
# 560-th output dim finished
# 561-th output dim finished
# 562-th output dim finished
# 563-th output dim finished
# 564-th output dim finished
# 565-th output dim finished
# 566-th output dim finished
# 567-th output dim finished
# 568-th output dim finished
# 569-th output dim finished
# 570-th output dim finished
# 571-th output dim finished
# 572-th output dim finished
# 573-th output dim finished
# 574-th output dim finished
# 575-th output dim finished
# 576-th output dim finished
# 577-th output dim finished
# 578-th output dim finished
# 579-th output dim finished
# 580-th output dim finished
# 581-th output dim finished
# 582-th output dim finished
# 583-th output dim finished
# 584-th output dim finished
# 585-th output dim finished
# 586-th output dim finished
# 587-th output dim finished
# 588-th output dim finished
# 589-th output dim finished
# 590-th output dim finished
# 591-th output dim finished
# 592-th output dim finished
# 593-th output dim finished
# 594-th output dim finished
# 595-th output dim finished
# 596-th output dim finished
# 597-th output dim finished
# 598-th output dim finished
# 599-th output dim finished
# 600-th output dim finished
# 601-th output dim finished
# 602-th output dim finished
# 603-th output dim finished
# 604-th output dim finished
# 605-th output dim finished
# 606-th output dim finished
# 607-th output dim finished
# 608-th output dim finished
# 609-th output dim finished
# 610-th output dim finished
# 611-th output dim finished
# 612-th output dim finished
# 613-th output dim finished
# 614-th output dim finished
# 615-th output dim finished
# 616-th output dim finished
# 617-th output dim finished
# 618-th output dim finished
# 619-th output dim finished
# 620-th output dim finished
# 621-th output dim finished
# 622-th output dim finished
# 623-th output dim finished
# 624-th output dim finished
# 625-th output dim finished
# 626-th output dim finished
# 627-th output dim finished
# 628-th output dim finished
# 629-th output dim finished
# 630-th output dim finished
# 631-th output dim finished
# 632-th output dim finished
# 633-th output dim finished
# 634-th output dim finished
# 635-th output dim finished
# 636-th output dim finished
# 637-th output dim finished
# 638-th output dim finished
# 639-th output dim finished
# 640-th output dim finished
# 641-th output dim finished
# 642-th output dim finished
# 643-th output dim finished
# 644-th output dim finished
# 645-th output dim finished
# 646-th output dim finished
# 647-th output dim finished
# 648-th output dim finished
# 649-th output dim finished
# 650-th output dim finished
# 651-th output dim finished
# 652-th output dim finished
# 653-th output dim finished
# 654-th output dim finished
# 655-th output dim finished
# 656-th output dim finished
# 657-th output dim finished
# 658-th output dim finished
# 659-th output dim finished
# 660-th output dim finished
# 661-th output dim finished
# 662-th output dim finished
# 663-th output dim finished
# 664-th output dim finished
# 665-th output dim finished
# 666-th output dim finished
# 667-th output dim finished
# 668-th output dim finished
# 669-th output dim finished
# 670-th output dim finished
# 671-th output dim finished
# 672-th output dim finished
# 673-th output dim finished
# 674-th output dim finished
# 675-th output dim finished
# 676-th output dim finished
# 677-th output dim finished
# 678-th output dim finished
# 679-th output dim finished
# 680-th output dim finished
# 681-th output dim finished
# 682-th output dim finished
# 683-th output dim finished
# 684-th output dim finished
# 685-th output dim finished
# 686-th output dim finished
# 687-th output dim finished
# 688-th output dim finished
# 689-th output dim finished
# 690-th output dim finished
# 691-th output dim finished
# 692-th output dim finished
# 693-th output dim finished
# 694-th output dim finished
# 695-th output dim finished
# 696-th output dim finished
# 697-th output dim finished
# 698-th output dim finished
# 699-th output dim finished
# 700-th output dim finished
# 701-th output dim finished
# 702-th output dim finished
# 703-th output dim finished
# 704-th output dim finished
# 705-th output dim finished
# 706-th output dim finished
# 707-th output dim finished
# 708-th output dim finished
# 709-th output dim finished
# 710-th output dim finished
# 711-th output dim finished
# 712-th output dim finished
# 713-th output dim finished
# 714-th output dim finished
# 715-th output dim finished
# 716-th output dim finished
# 717-th output dim finished
# 718-th output dim finished
# 719-th output dim finished
# 720-th output dim finished
# 721-th output dim finished
# 722-th output dim finished
# 723-th output dim finished
# 724-th output dim finished
# 725-th output dim finished
# 726-th output dim finished
# 727-th output dim finished
# 728-th output dim finished
# 729-th output dim finished
# 730-th output dim finished
# 731-th output dim finished
# 732-th output dim finished
# 733-th output dim finished
# 734-th output dim finished
# 735-th output dim finished
# 736-th output dim finished
# 737-th output dim finished
# 738-th output dim finished
# 739-th output dim finished
# 740-th output dim finished
# 741-th output dim finished
# 742-th output dim finished
# 743-th output dim finished
# 744-th output dim finished
# 745-th output dim finished
# 746-th output dim finished
# 747-th output dim finished
# 748-th output dim finished
# 749-th output dim finished
# 750-th output dim finished
# 751-th output dim finished
# 752-th output dim finished
# 753-th output dim finished
# 754-th output dim finished
# 755-th output dim finished
# 756-th output dim finished
# 757-th output dim finished
# 758-th output dim finished
# 759-th output dim finished
# 760-th output dim finished
# 761-th output dim finished
# 762-th output dim finished
# 763-th output dim finished
# 764-th output dim finished
# 765-th output dim finished
# 766-th output dim finished
# 767-th output dim finished
# 768-th output dim finished
# 769-th output dim finished
# 770-th output dim finished
# 771-th output dim finished
# 772-th output dim finished
# 773-th output dim finished
# 774-th output dim finished
# 775-th output dim finished
# 776-th output dim finished
# 777-th output dim finished
# 778-th output dim finished
# 779-th output dim finished
# 780-th output dim finished
# 781-th output dim finished
# 782-th output dim finished
# 783-th output dim finished
# 784-th output dim finished
# 785-th output dim finished
# 786-th output dim finished
# 787-th output dim finished
# 788-th output dim finished
# 789-th output dim finished
# 790-th output dim finished
# 791-th output dim finished
# 792-th output dim finished
# 793-th output dim finished
# 794-th output dim finished
# 795-th output dim finished
# 796-th output dim finished
# 797-th output dim finished
# 798-th output dim finished
# 799-th output dim finished
# 800-th output dim finished
# 801-th output dim finished
# 802-th output dim finished
# 803-th output dim finished
# 804-th output dim finished
# 805-th output dim finished
# 806-th output dim finished
# 807-th output dim finished
# 808-th output dim finished
# 809-th output dim finished
# 810-th output dim finished
# 811-th output dim finished
# 812-th output dim finished
# 813-th output dim finished
# 814-th output dim finished
# 815-th output dim finished
# 816-th output dim finished
# 817-th output dim finished
# 818-th output dim finished
# 819-th output dim finished
# 820-th output dim finished
# 821-th output dim finished
# 822-th output dim finished
# 823-th output dim finished
# 824-th output dim finished
# 825-th output dim finished
# 826-th output dim finished
# 827-th output dim finished
# 828-th output dim finished
# 829-th output dim finished
# 830-th output dim finished
# 831-th output dim finished
# 832-th output dim finished
# 833-th output dim finished
# 834-th output dim finished
# 835-th output dim finished
# 836-th output dim finished
# 837-th output dim finished
# 838-th output dim finished
# 839-th output dim finished
# 840-th output dim finished
# 841-th output dim finished
# 842-th output dim finished
# 843-th output dim finished
# 844-th output dim finished
# 845-th output dim finished
# 846-th output dim finished
# 847-th output dim finished
# 848-th output dim finished
# 849-th output dim finished
# 850-th output dim finished
# 851-th output dim finished
# 852-th output dim finished
# 853-th output dim finished
# 854-th output dim finished
# 855-th output dim finished
# 856-th output dim finished
# 857-th output dim finished
# 858-th output dim finished
# 859-th output dim finished
# 860-th output dim finished
# 861-th output dim finished
# 862-th output dim finished
# 863-th output dim finished
# 864-th output dim finished
# 865-th output dim finished
# 866-th output dim finished
# 867-th output dim finished
# 868-th output dim finished
# 869-th output dim finished
# 870-th output dim finished
# 871-th output dim finished
# 872-th output dim finished
# 873-th output dim finished
# 874-th output dim finished
# 875-th output dim finished
# 876-th output dim finished
# 877-th output dim finished
# 878-th output dim finished
# 879-th output dim finished
# 880-th output dim finished
# 881-th output dim finished
# 882-th output dim finished
# 883-th output dim finished
# 884-th output dim finished
# 885-th output dim finished
# 886-th output dim finished
# 887-th output dim finished
# 888-th output dim finished
# 889-th output dim finished
# 890-th output dim finished
# 891-th output dim finished
# 892-th output dim finished
# 893-th output dim finished
# 894-th output dim finished
# 895-th output dim finished
# 896-th output dim finished
# 897-th output dim finished
# 898-th output dim finished
# 899-th output dim finished
# 900-th output dim finished
# 901-th output dim finished
# 902-th output dim finished
# 903-th output dim finished
# 904-th output dim finished
# 905-th output dim finished
# 906-th output dim finished
# 907-th output dim finished
# 908-th output dim finished
# 909-th output dim finished
# 910-th output dim finished
# 911-th output dim finished
# 912-th output dim finished
# 913-th output dim finished
# 914-th output dim finished
# 915-th output dim finished
# 916-th output dim finished
# 917-th output dim finished
# 918-th output dim finished
# 919-th output dim finished
# 920-th output dim finished
# 921-th output dim finished
# 922-th output dim finished
# 923-th output dim finished
# 924-th output dim finished
# 925-th output dim finished
# 926-th output dim finished
# 927-th output dim finished
# 928-th output dim finished
# 929-th output dim finished
# 930-th output dim finished
# 931-th output dim finished
# 932-th output dim finished
# 933-th output dim finished
# 934-th output dim finished
# 935-th output dim finished
# 936-th output dim finished
# 937-th output dim finished
# 938-th output dim finished
# 939-th output dim finished
# 940-th output dim finished
# 941-th output dim finished
# 942-th output dim finished
# 943-th output dim finished
# 944-th output dim finished
# 945-th output dim finished
# 946-th output dim finished
# 947-th output dim finished
# 948-th output dim finished
# 949-th output dim finished
# 950-th output dim finished
# 951-th output dim finished
# 952-th output dim finished
# 953-th output dim finished
# 954-th output dim finished
# 955-th output dim finished
# 956-th output dim finished
# 957-th output dim finished
# 958-th output dim finished
# 959-th output dim finished
# 960-th output dim finished
# 961-th output dim finished
# 962-th output dim finished
# 963-th output dim finished
# 964-th output dim finished
# 965-th output dim finished
# 966-th output dim finished
# 967-th output dim finished
# 968-th output dim finished
# 969-th output dim finished
# 970-th output dim finished
# 971-th output dim finished
# 972-th output dim finished
# 973-th output dim finished
# 974-th output dim finished
# 975-th output dim finished
# 976-th output dim finished
# 977-th output dim finished
# 978-th output dim finished
# 979-th output dim finished
# 980-th output dim finished
# 981-th output dim finished
# 982-th output dim finished
# 983-th output dim finished
# 984-th output dim finished
# 985-th output dim finished
# 986-th output dim finished
# 987-th output dim finished
# 988-th output dim finished
# 989-th output dim finished
# 990-th output dim finished
# 991-th output dim finished
# 992-th output dim finished
# 993-th output dim finished
# 994-th output dim finished
# 995-th output dim finished
# 996-th output dim finished
# 997-th output dim finished
# 998-th output dim finished
# 999-th output dim finished
# Time for decoder training: 124.865775108 seconds
